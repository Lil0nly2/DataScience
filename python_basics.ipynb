# %% [markdown]
# <a href="https://colab.research.google.com/github/Lil0nly2/DataScience/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Basics: A Step-by-Step Hands-on Guide
#
# Welcome to this introductory Python tutorial! This notebook is designed to build your foundational programming skills step-by-step with simple examples and interactive code cells.
#
# ### What we will cover:
# 1. **Data Structures**: Lists (ordered collections) & Dictionaries (key-value pairs)
# 2. **Conditional Execution**: Making decisions with `if`, `elif`, and `else`
# 3. **Loops**: Repeating actions with `for` and `while` loops
# 4. **Custom Functions**: Writing reusable code blocks using `def`
# 5. **Putting It All Together**: A mini practice exercise
#
# ---

# %% [markdown]
# ## 1. Data Structures: Lists
#
# A **list** is an ordered, changeable collection of items. In Python, lists are defined using square brackets `[]`.
#
# ### Key Concepts:
# - Elements are separated by commas.
# - Python uses **0-based indexing** (the first element is index `0`).
# - You can use negative indices (e.g. `-1` refers to the last element).

# %%
# Step 1.1: Creating a list and accessing elements
fruits = ["apple", "banana", "cherry", "orange"]
print("Full list:", fruits)

# Accessing items by index
print("First item (index 0):", fruits[0])
print("Second item (index 1):", fruits[1])
print("Last item (index -1):", fruits[-1])
# Out:
# Full list: ['apple', 'banana', 'cherry', 'orange']
# First item (index 0): apple
# Second item (index 1): banana
# Last item (index -1): orange

# %% [markdown]
# ### Modifying Lists
# Lists are **mutable**, meaning you can add, remove, or change elements after creating the list.

# %%
# Step 1.2: Adding and removing items
fruits.append("mango")       # Add to the end
print("After append:", fruits)

fruits[1] = "blueberry"      # Change an element
print("After replacing index 1:", fruits)

fruits.remove("cherry")      # Remove a specific value
print("After remove:", fruits)

print("Number of items in list:", len(fruits))
# Out:
# After append: ['apple', 'banana', 'cherry', 'orange', 'mango']
# After replacing index 1: ['apple', 'blueberry', 'cherry', 'orange', 'mango']
# After remove: ['apple', 'blueberry', 'orange', 'mango']
# Number of items in list: 4

# %% [markdown]
# ---
# ## 2. Data Structures: Dictionaries
#
# A **dictionary** stores data in **key-value pairs**. It works like a real-world dictionary or contact list: you look up a **key** to get its associated **value**.
#
# ### Key Concepts:
# - Defined using curly braces `{}` with `key: value` pairs.
# - Keys must be unique (usually strings or numbers).
# - Fast lookup using `dict[key]` or `dict.get(key)`.

# %%
# Step 2.1: Creating a dictionary
student = {
    "name": "Maya",
    "age": 20,
    "major": "Computer Science",
    "gpa": 3.8
}
print("Student profile:", student)

# Accessing values by key
print("Name:", student["name"])
print("Major:", student.get("major"))
# Out:
# Student profile: {'name': 'Maya', 'age': 20, 'major': 'Computer Science', 'gpa': 3.8}
# Name: Maya
# Major: Computer Science

# %% [markdown]
# ### Updating Dictionaries
# You can add new keys or update existing values simply by assigning to them.

# %%
# Step 2.2: Adding new key-value pairs and updating
student["email"] = "maya@example.edu"   # Adding new key
student["gpa"] = 3.9                   # Updating existing key

print("Updated student profile:", student)
print("All keys:", list(student.keys()))
print("All values:", list(student.values()))

# %% [markdown]
# ---
# ## 3. Conditional Execution (`if`, `elif`, `else`)
#
# Conditionals allow your program to make decisions and take different paths depending on whether a condition is `True` or `False`.
#
# ### Comparison Operators:
# - `==` (equal to), `!=` (not equal to)
# - `>` (greater than), `<` (less than)
# - `>=` (greater than or equal to), `<=` (less than or equal to)
# - `in` (checks membership in a list, dict, or string)

# %%
# Step 3.1: Basic if-elif-else logic
score = 85

if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
elif score >= 70:
    grade = "C"
else:
    grade = "F"

print(f"Score: {score} -> Grade: {grade}")

# %% [markdown]
# ### Combining Conditions and Checking Membership
# You can combine conditions with `and`, `or`, `not`, and use `in` to inspect data structures.

# %%
# Step 3.2: Checking membership with 'in'
requested_fruit = "apple"

if requested_fruit in fruits:
    print(f"Yes, '{requested_fruit}' is in the list!")
else:
    print(f"Sorry, '{requested_fruit}' is not available.")

# Checking keys in a dictionary
if "email" in student and student["age"] >= 18:
    print(f"{student['name']} is an adult with a registered email.")

# %% [markdown]
# ---
# ## 4. Loops: Repeating Actions
#
# Loops allow you to run a block of code multiple times without repeating yourself.
#
# - **`for` loop**: Best when iterating through a known collection (such as items in a list or dictionary) or a specific range of numbers.
# - **`while` loop**: Repeats as long as a condition evaluates to `True`.

# %%
# Step 4.1: 'for' loop over a list
print("--- Iterating over a list ---")
for fruit in fruits:
    print(f"Item: {fruit.capitalize()}")

# Using range(start, stop) to count
print("\n--- Counting from 1 to 5 ---")
for number in range(1, 6):
    print(f"Step {number}")

# %% [markdown]
# ### Looping Through Dictionaries
# Use `.items()` to loop through both **keys** and **values** together.

# %%
# Step 4.2: Iterating over key-value pairs in a dictionary
print("--- Student Info Card ---")
for key, value in student.items():
    print(f"{key.capitalize()}: {value}")

# %% [markdown]
# ### While Loops
# A `while` loop runs continuously until its condition turns `False`. Always make sure the condition can eventually end!

# %%
# Step 4.3: A simple countdown using a while loop
countdown = 5
print("Starting countdown...")

while countdown > 0:
    print(countdown)
    countdown -= 1  # Decrement by 1

print("Blast off! 🚀")

# %% [markdown]
# ---
# ## 5. Custom Functions (`def`)
#
# A **function** is a reusable block of code that performs a specific task. You define a function once, and can call it anytime.
#
# ### Anatomy of a Function:
# ```python
# def function_name(parameter1, parameter2="default"):
#     """Docstring explaining what the function does."""
#     # Code to execute
#     return result
# ```

# %%
# Step 5.1: A basic greeting function with a default parameter
def greet_user(name, title="Student"):
    """Return a friendly greeting with an optional title."""
    message = f"Hello, {title} {name}! Welcome to Python."
    return message

# Calling the function
print(greet_user("Alex"))
print(greet_user("Smith", title="Professor"))

# %% [markdown]
# ### Functions with Conditionals and Data Structures
# Functions often take lists or dictionaries as inputs, process them, and return a result.

# %%
# Step 5.2: Function to calculate average and pass/fail status
def calculate_grade_status(scores, passing_threshold=70):
    """Calculates average score and determines if student passed."""
    if not scores:  # Handle edge case: empty list
        return {"average": 0, "passed": False}

    average = sum(scores) / len(scores)
    passed = average >= passing_threshold

    return {
        "average": round(average, 1),
        "passed": passed
    }

# Testing the function with sample score lists
math_scores = [80, 85, 90, 75]
result = calculate_grade_status(math_scores)
print("Math Result:", result)

history_scores = [60, 65, 55]
result2 = calculate_grade_status(history_scores)
print("History Result:", result2)

# %% [markdown]
# ---
# ## 6. Putting It All Together: Classroom Gradebook
#
# Let's combine **lists**, **dictionaries**, **conditionals**, **loops**, and **functions** into a complete mini-project!

# %%
# Step 6.1: Classroom dataset (List of Dictionaries)
classroom = [
    {"name": "Alice", "scores": [88, 92, 79], "attendance": 95},
    {"name": "Bob", "scores": [65, 70, 58], "attendance": 80},
    {"name": "Charlie", "scores": [95, 98, 100], "attendance": 98},
    {"name": "Diana", "scores": [72, 75, 78], "attendance": 68}
]

# Step 6.2: Custom function to evaluate a single student
def evaluate_student(student_record):
    """Evaluates a student based on score average and attendance."""
    name = student_record["name"]
    scores = student_record["scores"]
    attendance = student_record["attendance"]

    avg_score = sum(scores) / len(scores)

    # Conditional decision
    if avg_score >= 70 and attendance >= 75:
        status = "Pass (Good Standing)"
    elif avg_score >= 70 and attendance < 75:
        status = "Pass (Low Attendance Warning)"
    else:
        status = "Needs Improvement"

    return name, round(avg_score, 1), status

# Step 6.3: Loop through the classroom and print the report
print("=" * 48)
print("          CLASSROOM PERFORMANCE REPORT          ")
print("=" * 48)

for student_entry in classroom:
    name, avg, status = evaluate_student(student_entry)
    print(f"• {name:<10} | Avg: {avg:>5.1f} | Status: {status}")

print("=" * 48)

# %% [markdown]
# ## 🎓 Summary & Cheat Sheet
#
# | Concept | Syntax / Example | Purpose |
# | :--- | :--- | :--- |
# | **List** | `[1, 2, 3]`, `.append()`, `[0]` | Ordered, indexed sequence of items |
# | **Dictionary** | `{"key": "value"}`, `.get()` | Key-value store for structured records |
# | **Conditionals** | `if`, `elif`, `else` | Branching logic based on boolean truth |
# | **For Loop** | `for item in sequence:` | Iterating through collections or ranges |
# | **While Loop** | `while condition:` | Repeating while a condition remains True |
# | **Function** | `def name(args): return result` | Modular, reusable logic blocks |
#
# ### Suggested Exercises for Students:
# 1. Add a 5th student to the `classroom` list and re-run the report cell.
# 2. Modify `evaluate_student` to give an "Honor Roll" status to students with an average score >= 90.
# 3. Write a function `get_top_student(classroom)` that finds and returns the student with the highest average.
